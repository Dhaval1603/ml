# %%
import pandas as pd

# %%
data=pd.read_excel('/content/drive/MyDrive/ML Live Flight Fare Resourses16963295320.xlsx')

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
data[(data["Source"]=="Delhi")&(data["Destination"]=="Cochin")]["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      3185
# 2 stops     1113
# non-stop     213
# 3 stops       25
# Name: count, dtype: int64

# %%
data.fillna("1 stop",inplace=True)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.drop(columns=["Route","Additional_Info"],inplace=True)

# %%
data.fillna("1 stop",inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price
# 0      01:10 22 Mar   2h 50m    non-stop   3897
# 1             13:15   7h 25m     2 stops   7662
# 2      04:25 10 Jun      19h     2 stops  13882
# 3             23:30   5h 25m      1 stop   6218
# 4             21:35   4h 45m      1 stop  13302
# ...             ...      ...         ...    ...
# 10678         22:25   2h 30m    non-stop   4107
# 10679         23:20   2h 35m    non-stop   4145
# 10680         11:20       3h    non-stop   7229
# 10681         14:10   2h 40m    non-stop  12648
# 10682         19:15   8h 20m     2 stops  11753
#
# [10683 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10683 non-null  object
#  8   Price            10683 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 751.3+ KB

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data["j_date"]=pd.to_datetime(data["Date_of_Journey"]).dt.day
data["j_mon"]=pd.to_datetime(data["Date_of_Journey"]).dt.month

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price  j_date  j_mon
# 0      01:10 22 Mar   2h 50m    non-stop   3897      24      3
# 1             13:15   7h 25m     2 stops   7662       1      5
# 2      04:25 10 Jun      19h     2 stops  13882       9      6
# 3             23:30   5h 25m      1 stop   6218      12      5
# 4             21:35   4h 45m      1 stop  13302       1      3
# ...             ...      ...         ...    ...     ...    ...
# 10678         22:25   2h 30m    non-stop   4107       9      4
# 10679         23:20   2h 35m    non-stop   4145      27      4
# 10680         11:20       3h    non-stop   7229      27      4
# 10681         14:10   2h 40m    non-stop  12648       1      3
# 10682         19:15   8h 20m     2 stops  11753       9      5
#
# [10683 rows x 11 columns]

# %%
data["d_hr"]=pd.to_datetime(data["Dep_Time"]).dt.hour
data["d_min"]=pd.to_datetime(data["Dep_Time"]).dt.minute
data["a_hr"]=pd.to_datetime(data["Arrival_Time"]).dt.hour
data["a_min"]=pd.to_datetime(data["Arrival_Time"]).dt.minute

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price  j_date  j_mon  d_hr  d_min  \
# 0      01:10 22 Mar   2h 50m    non-stop   3897      24      3    22     20
# 1             13:15   7h 25m     2 stops   7662       1      5     5     50
# 2      04:25 10 Jun      19h     2 stops  13882       9      6     9     25
# 3             23:30   5h 25m      1 stop   6218      12      5    18      5
# 4             21:35   4h 45m      1 stop  13302       1      3    16     50
# ...             ...      ...         ...    ...     ...    ...   ...    ...
# 10678         22:25   2h 30m    non-stop   4107       9      4    19     55
# 10679         23:20   2h 35m    non-stop   4145      27      4    20     45
# 10680         11:20       3h    non-stop   7229      27      4     8     20
# 10681         14:10   2h 40m    non-stop  12648       1      3    11     30
# 10682         19:15   8h 20m     2 stops  11753       9      5    10     55
#
#        a_hr  a_min
# 0         1     10
# 1        13     15
# 2         4     25
# 3        23     30
# 4        21     35
# ...     ...    ...
# 10678    22     25
# 10679    23     20
# 10680    11     20
# 10681    14     10
# 10682    19     15
#
# [10683 rows x 15 columns]

# %%
lis=data["Duration"]

# %%
new_lis=[]
for i in lis:
    if len(i.split(" "))==1:
        if "m" in i:
            i="0h"+i
        else:
            i=i+"0m"

    new_lis.append(i)

# %%
data["Duration"]=new_lis

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price  j_date  j_mon  d_hr  d_min  \
# 0      01:10 22 Mar   2h 50m    non-stop   3897      24      3    22     20
# 1             13:15   7h 25m     2 stops   7662       1      5     5     50
# 2      04:25 10 Jun    19h0m     2 stops  13882       9      6     9     25
# 3             23:30   5h 25m      1 stop   6218      12      5    18      5
# 4             21:35   4h 45m      1 stop  13302       1      3    16     50
# ...             ...      ...         ...    ...     ...    ...   ...    ...
# 10678         22:25   2h 30m    non-stop   4107       9      4    19     55
# 10679         23:20   2h 35m    non-stop   4145      27      4    20     45
# 10680         11:20     3h0m    non-stop   7229      27      4     8     20
# 10681         14:10   2h 40m    non-stop  12648       1      3    11     30
# 10682         19:15   8h 20m     2 stops  11753       9      5    10     55
#
#        a_hr  a_min
# 0         1     10
# 1        13     15
# 2         4     25
# 3        23     30
# 4        21     35
# ...     ...    ...
# 10678    22     25
# 10679    23     20
# 10680    11     20
# 10681    14     10
# 10682    19     15
#
# [10683 rows x 15 columns]

# %%
data["dur_hr"]=data["Duration"].str.split("h").str[0].replace("h","",regex=True).astype(int)
data["dur_min"]=data["Duration"].str.split("h").str[1].replace("m","",regex=True).astype(int)

# %%
data.drop(columns=["Dep_Time","Arrival_Time","Duration","Date_of_Journey"],inplace=True)

# %%
data
# Out:
#            Airline    Source Destination Total_Stops  Price  j_date  j_mon  \
# 0           IndiGo  Banglore   New Delhi    non-stop   3897      24      3
# 1        Air India   Kolkata    Banglore     2 stops   7662       1      5
# 2      Jet Airways     Delhi      Cochin     2 stops  13882       9      6
# 3           IndiGo   Kolkata    Banglore      1 stop   6218      12      5
# 4           IndiGo  Banglore   New Delhi      1 stop  13302       1      3
# ...            ...       ...         ...         ...    ...     ...    ...
# 10678     Air Asia   Kolkata    Banglore    non-stop   4107       9      4
# 10679    Air India   Kolkata    Banglore    non-stop   4145      27      4
# 10680  Jet Airways  Banglore       Delhi    non-stop   7229      27      4
# 10681      Vistara  Banglore   New Delhi    non-stop  12648       1      3
# 10682    Air India     Delhi      Cochin     2 stops  11753       9      5
#
#        d_hr  d_min  a_hr  a_min  dur_hr  dur_min
# 0        22     20     1     10       2       50
# 1         5     50    13     15       7       25
# 2         9     25     4     25      19        0
# 3        18      5    23     30       5       25
# 4        16     50    21     35       4       45
# ...     ...    ...   ...    ...     ...      ...
# 10678    19     55    22     25       2       30
# 10679    20     45    23     20       2       35
# 10680     8     20    11     20       3        0
# 10681    11     30    14     10       2       40
# 10682    10     55    19     15       8       20
#
# [10683 rows x 13 columns]

# %%
data["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
data["Total_Stops"].replace("non-stop","0 STOP",inplace=True)
data["Total_Stops"].replace("[A-Za-z]","",regex=True,inplace=True)
data["Total_Stops"]=data["Total_Stops"].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
x=data.drop(["Price","Source","dur_min","a_min"],axis=1)
y=data.Price

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=10)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.44198108685752735

# %%
model.score(x_test,y_test)
# Out:
# 0.4154374084345003

# %%
from sklearn.model_selection import cross_val_score,KFold

# %%
K=KFold(n_splits=4)

# %%
cross_val_score(LinearRegression(),x,y,cv=K).mean()
# Out:
# np.float64(0.43480872718391766)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
lis=[DecisionTreeRegressor,KNeighborsRegressor,SVR,RandomForestRegressor]

# %%
for i in lis:
    K=KFold(n_splits=4)
    print(i)
    print(cross_val_score(i(),x,y,cv=K).mean())
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.7000876688951088
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.6076438240225481
# <class 'sklearn.svm._classes.SVR'>
# 0.004741875489708697
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.7976621531917637

# %%
model=RandomForestRegressor(n_estimators=900,random_state=20,max_depth=3)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=900, random_state=20)

# %%
model.score(x_train,y_train)
# Out:
# 0.5449265347322311

# %%
model.score(x_test,y_test)
# Out:
# 0.5236692579844715

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random=RandomizedSearchCV(RandomForestRegressor(),param_distributions={"n_estimators":[900,800,1000],"random_state":[10,20,30],"max_depth":[2,3,4]},n_iter=10,cv=K,verbose=2)

# %%
random.fit(x,y)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV] END .....max_depth=2, n_estimators=900, random_state=20; total time=   4.6s
# [CV] END .....max_depth=2, n_estimators=900, random_state=20; total time=   5.8s
# [CV] END .....max_depth=2, n_estimators=900, random_state=20; total time=   4.8s
# [CV] END .....max_depth=2, n_estimators=900, random_state=20; total time=   5.6s
# [CV] END .....max_depth=3, n_estimators=800, random_state=20; total time=   7.9s
# [CV] END .....max_depth=3, n_estimators=800, random_state=20; total time=   6.2s
# [CV] END .....max_depth=3, n_estimators=800, random_state=20; total time=   6.6s
# [CV] END .....max_depth=3, n_estimators=800, random_state=20; total time=   6.0s
# [CV] END .....max_depth=3, n_estimators=900, random_state=10; total time=   7.7s
# [CV] END .....max_depth=3, n_estimators=900, random_state=10; total time=   6.7s
# [CV] END .....max_depth=3, n_estimators=900, random_state=10; total time=   7.6s
# [CV] END .....max_depth=3, n_estimators=900, random_state=10; total time=   6.7s
# [CV] END ....max_depth=4, n_estimators=1000, random_state=30; total time=  10.2s
# [CV] END ....max_depth=4, n_estimators=1000, random_state=30; total time=  10.3s
# [CV] END ....max_depth=4, n_estimators=1000, random_state=30; total time=  10.2s
# [CV] END ....max_depth=4, n_estimators=1000, random_state=30; total time=   9.2s
# [CV] END .....max_depth=2, n_estimators=800, random_state=20; total time=   5.8s
# [CV] END .....max_depth=2, n_estimators=800, random_state=20; total time=   4.3s
# [CV] END .....max_depth=2, n_estimators=800, random_state=20; total time=   4.5s
# [CV] END .....max_depth=2, n_estimators=800, random_state=20; total time=   5.6s
# [CV] END ....max_depth=2, n_estimators=1000, random_state=10; total time=   5.5s
# [CV] END ....max_depth=2, n_estimators=1000, random_state=10; total time=   6.3s
# [CV] END ....max_depth=2, n_estimators=1000, random_state=10; total time=   5.9s
# [CV] END ....max_depth=2, n_estimators=1000, random_state=10; total time=   5.6s
# [CV] END .....max_depth=3, n_estimators=800, random_state=10; total time=   7.0s
# [CV] END .....max_depth=3, n_estimators=800, random_state=10; total time=   6.0s
# [CV] END .....max_depth=3, n_estimators=800, random_state=10; total time=   6.9s
# [CV] END .....max_depth=3, n_estimators=800, random_state=10; total time=   6.0s
# [CV] END .....max_depth=4, n_estimators=900, random_state=20; total time=   9.3s
# [CV] END .....max_depth=4, n_estimators=900, random_state=20; total time=   8.8s
# [CV] END .....max_depth=4, n_estimators=900, random_state=20; total time=   8.6s
# [CV] END .....max_depth=4, n_estimators=900, random_state=20; total time=   9.2s
# [CV] END ....max_depth=3, n_estimators=1000, random_state=10; total time=   7.2s
# [CV] END ....max_depth=3, n_estimators=1000, random_state=10; total time=   8.4s
# [CV] END ....max_depth=3, n_estimators=1000, random_state=10; total time=   8.0s
# [CV] END ....max_depth=3, n_estimators=1000, random_state=10; total time=   7.9s
# [CV] END .....max_depth=4, n_estimators=800, random_state=10; total time=   8.4s
# [CV] END .....max_depth=4, n_estimators=800, random_state=10; total time=   7.4s
# [CV] END .....max_depth=4, n_estimators=800, random_state=10; total time=   8.1s
# [CV] END .....max_depth=4, n_estimators=800, random_state=10; total time=   7.3s
# RandomizedSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=False),
#                    estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [2, 3, 4],
#                                         'n_estimators': [900, 800, 1000],
#                                         'random_state': [10, 20, 30]},
#                    verbose=2)

# %%
random.best_params_

# %%
pd.Series(model.feature_importances_,index=x.columns).plot(kind="bar")
# Out:
# <Axes: >

# %%
x.drop(["Source","dur_min","a_min"],axis=1,inplace=True)

# %%
x
# Out:
#        Airline  Destination  Total_Stops  j_date  j_mon  d_hr  d_min  a_hr  \
# 0            3            5            0      24      3    22     20     1
# 1            1            0            2       1      5     5     50    13
# 2            4            1            2       9      6     9     25     4
# 3            3            0            1      12      5    18      5    23
# 4            3            5            1       1      3    16     50    21
# ...        ...          ...          ...     ...    ...   ...    ...   ...
# 10678        0            0            0       9      4    19     55    22
# 10679        1            0            0      27      4    20     45    23
# 10680        4            2            0      27      4     8     20    11
# 10681       10            5            0       1      3    11     30    14
# 10682        1            1            2       9      5    10     55    19
#
#        dur_hr
# 0           2
# 1           7
# 2          19
# 3           5
# 4           4
# ...       ...
# 10678       2
# 10679       2
# 10680       3
# 10681       2
# 10682       8
#
# [10683 rows x 9 columns]

# %%
import joblib

# %%
cd Downloads/
# Out:
# [Errno 2] No such file or directory: 'Downloads/'
# /content

# %%
joblib.dump(model,"ml_model.pkl")
# Out:
# ['ml_model.pkl']

# %%
import joblib

# %%
mode=joblib.load("ml_model.pkl")

# %%
mode
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=900, random_state=20)
